# %% [markdown]
# # data + program (go to) computer ------ output
# # traditional programming

# %% [markdown]
# # data + output(go to) computer =====> program
# # machine learning

# %% [markdown]
# # Machine learning is a branch of Artificial Intelligence that focuses on developing models and algorithms that let computers learn from data without being explicitly programmed for every task. In simple words, ML teaches systems to think and understand like humans by learning from the data.

# %% [markdown]
# # types of ML

# %% [markdown]
# # 1 Supervised Learning: Trains models on labeled data to predict or classify new, unseen data.

# %% [markdown]
# # 2 Unsupervised Learning: Finds patterns or groups in unlabeled data, like clustering or dimensionality reduction.

# %% [markdown]
# # 3 Reinforcement Learning: Learns through trial and error to maximize rewards, ideal for decision-making tasks.

# %% [markdown]
# # batch vs online ml

# %% [markdown]
# # Batch learning, also termed offline learning, is that type of learning where the model undergoes a training process from the entire batch of data. Normally, it involves feeding of what is referred to as batch data, which includes inputting all available data at once into the learning algorithm; a process which results in the creation of a model that can be used to make the prediction. Once trained, the model is not updated by default; the only way to rebuild a given model is restructuring it with new data.
#
# # Key Characteristics of Batch Learning:
#
# # Data Processing: Trained on the entire dataset and focused on deep learning algorithms.
# # Model Update: Parameters in a model are updated rarely, and earlier they may need to be trained again with the entire dataset.
# # Resource-Intensive: Extremely computationally and memory-intensive, where large amount of data is crunched.
# # Predictive Performance: In some cases, it may achieve very high accuracy because of a detailed analysis of the data used in the training phase.

# %% [markdown]
# # Machine learning with online learning is completed in stages, where the learned model is updated with a new model as new data arrives. Unlike machine learning models that can run on a dataset as a whole, the model makes a rather continuous or intermittent update with new data or a successive portion of it. This makes the model reactive to novelties and variations of the data flow and can be implemented easily.
#
# # Key Characteristics of Online Learning:
#
# # Data Processing: Analyzes arriving data in small packets that come in a stream.
# # Model Update: Models are changing all over the time, mostly in a real-time or nearly real-time environment.
# # Resource Efficient: Sought in less quantity as well at any specific time in the computation course of action.
# # Adaptive Performance: Able to make adjustments to the results of data regardless of the changes, which is good for changing climates.

# %% [markdown]
# # What is Model-Based Learning?
# ## Model-Based Learning focuses on building a mathematical or algorithmic model that generalizes the patterns and relationships within the training data. This model is then used to make predictions on new, unseen data.
#
# # How It Works:
# ##  A model is trained using the entire dataset.
# ## The model learns the underlying patterns and relationships.
# ## Predictions are made based on this learned knowledge, without relying on the original training data.
# # Examples:
# ### Linear Regression: Establishes a linear relationship between input and output.
# ### Decision Trees: Creates a tree structure to make decisions based on feature splits.
# ### Neural Networks: Mimics the human brain to identify patterns in complex data.
# # Advantages:
# ### Faster predictions after training.
# ### Memory-efficient, as it doesn’t require storing the entire dataset.
# ### Suitable for large datasets and complex problems.
# # Limitations:
# ### Requires retraining for new data.
# ### Model accuracy depends on the quality and representativeness of the training data.

# %% [markdown]
# # What is Instance-Based Learning?
# ## Instance-Based Learning, on the other hand, memorizes the training data and uses it directly for making predictions. It does not generalize or create a standalone model but relies on comparing new data points to stored instances.
#
# # How It Works:
# ## Training data is stored as-is.
# ## Predictions are made by comparing new data points to the closest or most similar instances using distance metrics like Euclidean distance.
# # Examples:
# ### k-Nearest Neighbors (k-NN): Identifies the ‘k’ closest instances to predict the outcome.
# ### Support Vector Machines (SVM): Uses specific data points (support vectors) to define boundaries.
# # Advantages:
# ### Easy to implement and understand.
# ### Adapts naturally to new data since no retraining is needed.
# # Limitations:
# ### Computationally expensive for large datasets due to similarity calculations.
# ### Storage-intensive as it requires keeping all training data.

# %% [markdown]
# # challenges of ML
# ## 1. Data Quality and Availability
#
# ## 2. Imbalanced Datasets
#
# ## 3. Overfitting and Underfitting
#
# ## 4. Model Interpretability and Explainability
#
# ## 5. Model Deployment and Integration
#
# ## 6. Model Drift and Continuous Monitoring
#
# ## 7. Data Privacy and Security Concerns
#
# ## 8. Bias and Fairness in Models
#
# ## 9. Lack of Domain Expertise
#
# ## 10. Rapid Technological Evolution and Skill Gaps

# %% [markdown]
# # apllication of ML
# ## 1. Healthcare and Medical Diagnosis
# ### Disease Detection
# ### Predictive Analytics
# ### Drug Discovery
#
# ## 2. Smart Assistants and Human-Machine Interaction
# ### Voice Assistants
# ### Voice Search & Transcription
# ### Chatbots
#
# ## 3. Personalized Recommendations and User Experience
# ### Streaming Platforms
# ### E-commerce
# ### Social Media
#
# ## 4. Fraud Detection and Financial Forecasting
# ### Transaction Monitoring
# ### Loan Risk Assessment
# ### Stock Market Prediction
#
# ## 5. Autonomous Vehicles and Smart Mobility
# ### Computer Vision
# ### Sensor Fusion
# ### Sensor Fusion

# %% [markdown]
# # Machine Learning Development Life Cycle
# ## Step 1: Problem Definition
# ## Step 2: Data Collection
# ## Step 3: Data Cleaning and Preprocessing
# ## Step 4: Exploratory Data Analysis (EDA)
# ## Step 5: Feature Engineering and Selection
# ## Step 6: Model Selection
# ## Step 7: Model Training
# ## Step 8: Model Evaluation and Tuning
# ## Step 9: Model Deployment
# ## Step 10: Model Monitoring and Maintenance

# %% [markdown]
# # Tensors are multidimensional arrays, fundamental to TensorFlow's operations and computations. Understanding key concepts like tensor shape, size, rank, and dimension is crucial for effectively using TensorFlow in machine learning projects.
#
#
# # What is Tensor Shape?
# ## Tensor shape refers to the layout or structure of a tensor, which defines the number of dimensions and the size of each dimension in the tensor. It describes how many elements are along each axis of the tensor
#
# # What is Tensor Size?
# ## Tensor size refers to the total number of elements in a tensor. It is the product of all the dimensions (sizes) of the tensor. In other words, it represents the total amount of data stored in the tensor.
#
# # What is Tensor Rank?
# ## Tensor rank, also known as the tensor's number of dimensions, is a fundamental concept in TensorFlow. It indicates the number of dimensions present in a tensor.
#
# ## Here's a brief overview of tensor rank:
# ### Rank 0: Scalars. Tensors of rank 0 represent single values.
# ### Rank 1: Vectors. Tensors of rank 1 have one dimension and represent arrays of values.
# ### Rank 2: Matrices. Tensors of rank 2 have two dimensions and represent 2D arrays of values.
# ### Rank 3 and above: Tensors of rank 3 or higher have three or more dimensions and represent higher-dimensional arrays of values.
#
# # What is Tensor Dimension?
# ## Tensor dimension refers to the length along a particular axis of a tensor. In simpler terms, it is the size or extent of a tensor along a specific direction. Each axis of a tensor corresponds to a dimension, and the number of dimensions in a tensor is its rank.

# %% [markdown]
# ### 1d tensor or scalar ====> it's the collection of multiple 0D tensors.
# ### vector  ====> it's the collection of multiple scalars.
# ### metrice  ====> it's the collection of multiple vector.

# %% [markdown]
# ### no of ranks === Axix === no of dimensions

# %% [markdown]
# #### nlp is 3D tensor
# #### cv is 4D tensor
#
# #### Persistence of vision > human Eye and brain can only process 12 images per second only

# %%
# Churn rate measures the percentage of customers or revenue a business loses over a specific period.

# %% [markdown]
# # How to Frame Machine Learning Problems
# ### Framing a machine learning (ML) problem is a crucial step that involves defining the problem in terms that can be addressed using ML techniques. This process ensures that the problem is suitable for an ML solution and sets clear goals and success criteria.
#
# ## Define the Ideal Outcome and Model's Goal
# ### The first step is to define the ideal outcome and the model's goal. The ideal outcome is what you want your product or feature to achieve, independent of the ML model. The model's goal is what you want the model to do to achieve this outcome. For example, in a weather app, the ideal outcome might be to calculate precipitation in six-hour increments for a geographic region, and the model's goal would be to predict six-hour precipitation amounts for specific geographic regions.
#
# ## Identify the Model's Output
# ### Next, identify the type of output you need from the model. This depends on the specific context and constraints of your problem. If you need to classify something or make a numeric prediction, you'll likely use predictive ML. If you need to generate new content or produce output related to natural language understanding, you'll probably use generative AI.
#
# ## Predictive ML Outputs
# ### Classification: Predicts the category of the input data (e.g., spam or not spam).
#
# ### Regression: Predicts a numerical value (e.g., the number of views a video will get).
#
# ## steps involved
# #### 1 bussiness problem to Ml problem
# #### 2 types of problem
# #### 3 current solution
# #### 4 getting data
# #### 5 metrices to measure
# #### 6 online vs Batch?
# #### 7 check assumption
