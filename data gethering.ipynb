# %% [markdown]
# # csv
#
# ## A CSV (Comma-Separated Values) file is a plain text format used to store tabular data where each line represents a row and values are separated by a delimiter, typically a comma. It is widely supported by spreadsheet tools, databases, and programming languages, making it a universal choice for data exchange.
#
# ### Key characteristics include:
#
# #### Delimiters: Commonly commas, but can also be semicolons, tabs, or pipes.
#
# #### Quotes: Used to wrap values containing delimiters or special characters.
#
# #### Header rows: Optional first row describing column names.

# %% [markdown]
# ## TSV (Tab-Separated Values) file, a simple, plain-text format that organizes information in rows and columns using tabs as separators. TSV files are easy to read, highly compatible across tools, and ideal for clean, error-free data handling.

# %%
import pandas as pd
data = pd.read_csv("Indian_Kids_Screen_Time.csv")

# %%
data
# Out:
#       Age  Gender  ...                   Health_Impacts Urban_or_Rural
# 0      14    Male  ...           Poor Sleep, Eye Strain          Urban
# 1      11  Female  ...                       Poor Sleep          Urban
# 2      18  Female  ...                       Poor Sleep          Urban
# 3      15  Female  ...                              NaN          Urban
# 4      12  Female  ...              Poor Sleep, Anxiety          Urban
# ...   ...     ...  ...                              ...            ...
# 9707   17    Male  ...                       Poor Sleep          Urban
# 9708   17  Female  ...                       Poor Sleep          Rural
# 9709   16    Male  ...  Poor Sleep, Eye Strain, Anxiety          Rural
# 9710   17    Male  ...                       Poor Sleep          Urban
# 9711   15  Female  ...                          Anxiety          Urban
#
# [9712 rows x 8 columns]

# %%
# open csv file through url
 
import requests
from io import StringIO


url = "https://raw.githubusercontent.com/datasets/oil-prices/main/data/brent-daily.csv"
response = requests.get(url)
df = pd.read_csv(StringIO(response.text))
print(df.head())
# Out:
#          Date  Price
# 0  1987-05-20  18.63
# 1  1987-05-21  18.45
# 2  1987-05-22  18.55
# 3  1987-05-25  18.60
# 4  1987-05-26  18.63

# %%
# for tsv file
# data = pd.read_csv('Indian_Kids_Screen_Time.tsv',sep ="/t")

# if no columns names  use names parmeter
# data = pd.read_csv('Indian_Kids_Screen_Time.tsv',sep ="/t",names =["  ","  "])

# %% [markdown]
# # parmeter

# %%
1 # data = pd.read_csv("Indian_Kids_Screen_Time.csv",index_col =" Column name")
2 # data = pd.read_csv("Indian_Kids_Screen_Time.csv",header =1)
3 # data= pd.read_csv("Indian_Kids_Screen_Time.csv",use_cols=[" "," col names",""])
4 # data = pd.read_csv("Indian_Kids_Screen_Time.csv", usecol=["col name"],squeeze =True)
# Out:
# 4

# %%
#data = pd.read_csv("Indian_Kids_Screen_Time.csv",nrows=100)
# data = pd.read_csv("Indian_Kids_Screen_Time.csv",encoding ="latin-1")

# %% [markdown]
# # Json/SQL

# %% [markdown]
# # JSON (JavaScript Object Notation) is a lightweight, text-based format for storing and exchanging structured data. It is human-readable, easy to parse, and supported by almost all modern programming languages, making it a standard for APIs, configuration files, and data transfer between clients and servers.

# %%
import pandas as pd

# %%
import json

with open("sample.json", "r") as f:
    data = json.load(f)

print(data)
# Out:
# {'labels': {'HAPROXY_0_STICKY': 'true', 'HAPROXY_GROUP': 'external', 'HAPROXY_0_VHOST': 'data.lab.org'}, 'id': '/lab/big-databio', 'backoffFactor': 1.15, 'backoffSeconds': 1, 'constraints': [['@region', 'IS', 'uva-udc']], 'container': {'type': 'MESOS', 'volumes': [{'containerPath': '/usr/share/nginx/html', 'hostPath': '/mnt/qproject/lab/www', 'mode': 'RO'}, {'containerPath': '/var/log/nginx', 'hostPath': '/var/log/nginx', 'mode': 'RW'}], 'portMappings': [{'containerPort': 80, 'hostPort': 0, 'protocol': 'tcp'}], 'docker': {'image': 'databio/nginx-auto:latest', 'forcePullImage': True, 'parameters': []}}, 'cpus': 0.5, 'disk': 0, 'healthChecks': [{'gracePeriodSeconds': 5, 'ignoreHttp1xx': False, 'intervalSeconds': 3, 'maxConsecutiveFailures': 2, 'portIndex': 0, 'timeoutSeconds': 2, 'delaySeconds': 15, 'protocol': 'HTTP', 'path': '/'}], 'instances': 1, 'maxLaunchDelaySeconds': 300, 'mem': 512, 'gpus': 0, 'networks': [{'mode': 'container/bridge'}], 'requirePorts': False, 'upgradeStrategy':
# ...

# %%
df = pd.json_normalize(data)
print(df.head())
# Out:
#                  id  backoffFactor  backoffSeconds               constraints  \
# 0  /lab/big-databio           1.15               1  [[@region, IS, uva-udc]]
#
#    cpus  disk                                       healthChecks  instances  \
# 0   0.5     0  [{'gracePeriodSeconds': 5, 'ignoreHttp1xx': Fa...          1
#
#    maxLaunchDelaySeconds  mem  ...  container.type  \
# 0                    300  512  ...           MESOS
#
#                                    container.volumes  \
# 0  [{'containerPath': '/usr/share/nginx/html', 'h...
#
#                               container.portMappings  \
# 0  [{'containerPort': 80, 'hostPort': 0, 'protoco...
#
#       container.docker.image container.docker.forcePullImage  \
# 0  databio/nginx-auto:latest                            True
#
#   container.docker.parameters upgradeStrategy.maximumOverCapacity  \
# 0                          []                                   1
#
#   upgradeStrategy.minimumHealthCapacity  \
# ...

# %%
df.head(20)
# Out:
#                  id  backoffFactor  backoffSeconds               constraints  \
# 0  /lab/big-databio           1.15               1  [[@region, IS, uva-udc]]
#
#    cpus  disk                                       healthChecks  instances  \
# 0   0.5     0  [{'gracePeriodSeconds': 5, 'ignoreHttp1xx': Fa...          1
#
#    maxLaunchDelaySeconds  mem  ...  container.type  \
# 0                    300  512  ...           MESOS
#
#                                    container.volumes  \
# 0  [{'containerPath': '/usr/share/nginx/html', 'h...
#
#                               container.portMappings  \
# 0  [{'containerPort': 80, 'hostPort': 0, 'protoco...
#
#       container.docker.image container.docker.forcePullImage  \
# 0  databio/nginx-auto:latest                            True
#
#   container.docker.parameters upgradeStrategy.maximumOverCapacity  \
# 0                          []                                   1
#
#   upgradeStrategy.minimumHealthCapacity  \
# ...

# %%
pd.read_json("https://api.exchangerate-api.com/v4/latest/INR")
# Out:
#                              provider  \
# INR  https://www.exchangerate-api.com
# AED  https://www.exchangerate-api.com
# AFN  https://www.exchangerate-api.com
# ALL  https://www.exchangerate-api.com
# AMD  https://www.exchangerate-api.com
# ..                                ...
# YER  https://www.exchangerate-api.com
# ZAR  https://www.exchangerate-api.com
# ZMW  https://www.exchangerate-api.com
# ZWG  https://www.exchangerate-api.com
# ZWL  https://www.exchangerate-api.com
#
#                           WARNING_UPGRADE_TO_V6  \
# INR  https://www.exchangerate-api.com/docs/free
# AED  https://www.exchangerate-api.com/docs/free
# AFN  https://www.exchangerate-api.com/docs/free
# ALL  https://www.exchangerate-api.com/docs/free
# AMD  https://www.exchangerate-api.com/docs/free
# ..                                          ...
# YER  https://www.exchangerate-api.com/docs/free
# ZAR  https://www.exchangerate-api.com/docs/free
# ZMW  https://www.exchangerate-api.com/docs/free
# ...

# %% [markdown]
# # API

# %%
import requests

# %%
import requests

url = "https://linkedin-job-search-api.p.rapidapi.com/active-jb-7d"


headers = {
    "x-rapidapi-key": "ec429feb5cmsh68e227613cff6e5p1e0114jsn30539bdc1e32",
    "x-rapidapi-host": "linkedin-job-search-api.p.rapidapi.com"
}

response = requests.get(url, headers=headers)

print(response.status_code)
print(response.json())
# Out:
# 200
# ...

# %%
data = response.json()

df = pd.json_normalize(data)

print(df.head())
# Out:
#            id              date_posted                date_created  \
# 0  2197109623  2026-06-09T23:32:52.397  2026-06-09T23:32:52.452571
# 1  2197109488      2026-06-09T23:32:35  2026-06-09T23:32:43.717972
# 2  2197110052      2026-06-09T23:32:20  2026-06-09T23:33:16.843634
# 3  2197110061      2026-06-09T23:32:20  2026-06-09T23:33:17.398569
# 4  2197109284      2026-06-09T23:31:37  2026-06-09T23:32:28.089037
#
#                                      title  \
# 0                    Livestock Underwriter
# 1                 Business Systems Manager
# 2       Maintenance Tech II - Nights 2/2/3
# 3         Maintenance Tech II - Days 2/2/3
# 4  Lead - Strategic Inventory Distribution
#
#                                         organization  \
# 0                                            Palomar
# 1                                             TriNet
# 2                                      Michael Foods
# 3                                      Michael Foods
# ...

# %%
df
# Out:
#             id              date_posted                date_created  \
# 0   2197109623  2026-06-09T23:32:52.397  2026-06-09T23:32:52.452571
# 1   2197109488      2026-06-09T23:32:35  2026-06-09T23:32:43.717972
# 2   2197110052      2026-06-09T23:32:20  2026-06-09T23:33:16.843634
# 3   2197110061      2026-06-09T23:32:20  2026-06-09T23:33:17.398569
# 4   2197109284      2026-06-09T23:31:37  2026-06-09T23:32:28.089037
# ..         ...                      ...                         ...
# 95  2197109579      2026-06-09T23:28:36  2026-06-09T23:32:49.538398
# 96  2197109722      2026-06-09T23:28:36  2026-06-09T23:32:58.506909
# 97  2197109895      2026-06-09T23:28:36   2026-06-09T23:33:09.26058
# 98  2197109944      2026-06-09T23:28:35   2026-06-09T23:33:12.01619
# 99  2197110169      2026-06-09T23:28:34  2026-06-09T23:33:21.795057
#
#                                       title  \
# 0                     Livestock Underwriter
# 1                  Business Systems Manager
# ...
