# %%
from sklearn.datasets import make_classification
from collections import Counter

X, y = make_classification(n_samples=5000, weights=[0.9, 0.1], random_state=42)
print(Counter(y))
# Out:
# Counter({0: 4477, 1: 523})

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler()
X_under, y_under = rus.fit_resample(X, y)

print(Counter(y_under))
# Out:
# Counter({0: 523, 1: 523})

# %%
from imblearn.over_sampling import SMOTE

smote = SMOTE()
X_over, y_over = smote.fit_resample(X, y)

print(Counter(y_over))
# Out:
# Counter({0: 4477, 1: 4477})

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report

def train_model(X, y):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    model = RandomForestClassifier()
    model.fit(X_train, y_train)
    
    y_pred = model.predict(X_test)
    print(classification_report(y_test, y_pred))

# %%
train_model(X, y)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98       908
#            1       0.87      0.71      0.78        92
#
#     accuracy                           0.96      1000
#    macro avg       0.92      0.85      0.88      1000
# weighted avg       0.96      0.96      0.96      1000

# %%
train_model(X_under, y_under)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      0.92      0.86       105
#            1       0.91      0.77      0.84       105
#
#     accuracy                           0.85       210
#    macro avg       0.86      0.85      0.85       210
# weighted avg       0.86      0.85      0.85       210

# %%
train_model(X_over, y_over)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       882
#            1       0.95      0.95      0.95       909
#
#     accuracy                           0.95      1791
#    macro avg       0.95      0.95      0.95      1791
# weighted avg       0.95      0.95      0.95      1791
