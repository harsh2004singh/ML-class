# %% [markdown]
# # feature engineering is a process of using domain knowledge to extract the features from row data.These feature can we used to imporve the performance of Ml Algorithms

# %% [markdown]
# # feature engineering
#
# ### feature tranformation
# ### features construction
# ### features selectiom
# ### features extraction

# %% [markdown]
# # feature tranformation
# ### missing values
# ### handling categorical values
# ### outlier detection
# ### features Scaling

# %% [markdown]
# # features construction
# # Feature construction is the process of creating new, meaningful features from existing data to improve machine learning model performance.

# %% [markdown]
# # features selection
#
# # Feature selection in Machine Learning is the process of selecting the most relevant features (variables) from your dataset to improve model performance, reduce overfitting, and make models easier to interpret.
